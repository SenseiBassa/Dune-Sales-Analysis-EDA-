# %% [markdown]
# <a href="https://colab.research.google.com/github/SenseiBassa/Dune-Sales-Analysis-EDA-/blob/main/Dune_Sales_Exploratory_Data_Analysis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Bassa Joshua Samuel**
#
# ---
#
#
#
# ## **Dune Sales Analysis**
#
# ---
#
# Dune is a reputable global offering a diverse selection including accessories, clothin, and phones. With a growing presence in 1 countries and of over 70,000 employees, the company prides itself on providing affordable options for everyone. From fashion-forward trendsetters to multi-generational families, Dune strives to offer great quality essentials and standout styles that cater to a wide range of customers.
#
# ## **Business Objective**
#
# ---
#
# As the newly appointed Data Scientist, my first task is to analyze the company's sales data from the previous year and provide acttionable insights and  recommendations. This analysis wil help identify areas of opportunity and inform future business decisions aimed at improving performance and increasing profitability.

# %% [markdown]
# # Exploratory Data Analysis
#
# Exploratory Data Analysis (EDA) is the process of analyzing and summarizing data in order to ain insights and uderstanding of the underlying patterns and relationships. The main objrctive of EDA is to identify and explore the main characteristics and patterns of the data, and to identify any anomalies or outliers that may impact subsequent analysis.
#
# EDA typically incolves a number of steps including:
#
#
# 1. Data Cleaning - Data cleaning involves removing or correcting any errors or inconsistencies in the data, such as missing values or incorrect values.
# 2. Data Visualization - Data Visualization techniques are then used to grapically represent the data and identify qny trends or patterns.
# 3.Statistical analysis - Statistical analysis is used to identify any relationships between variables and to tesrt hypotheses about the data. This may involve calculating summary statisticsn such as mean and standard deviation, and performing tests such as correalation analysis and hypothesis testing.

# %%
# !pip install missingno

# %%
# Import libraries 
import pandas as pd # Data processing
import matplotlib.pyplot as plt # Data visualiztion
import seaborn as sns # Data visualiztion
import missingno as msno # Missing data - Data visualization 
from collections import Counter # Counting

# %%
# load the dataset

import pandas as pd

df = pd.read_csv(r"C:\Users\Uncle Baby\Desktop\Gondolin\10Alytics\Week 14 Dune Sales EDA\dune-sales-data.csv")

# %%
# Print the top rows
df.head() # Top 5 rows (by default but you can specify)
# Out:
#          Date Customer Sales Person  Customer_Age Customer_Gender State  \
# 0  02/19/2016     High        Segun            29               F  Abia
# 1  02/20/2016     High        Segun            29               F  Abia
# 2  02/27/2016     High        Segun            29               F  Abia
# 3  03/12/2016     High        Segun            29               F  Abia
# 4  03/12/2016     High        Segun            29               F  Abia
#
#   Product_Category Sub_Category Payment Option  Quantity  Unit_Cost  \
# 0      Accessories     Keyboard         Online       1.0      80.00
# 1         Clothing  Polo shirts         Online       2.0      24.50
# 2      Accessories     Keyboard         Online       3.0       3.67
# 3      Accessories     Keyboard         Online       2.0      87.50
# 4      Accessories     Keyboard         Online       3.0      35.00
#
#    Unit_Price
# 0      109.00
# 1       28.50
# 2        5.00
# 3      116.50
# 4       41.67

# %%
# Print the bottom rows
df.tail() # Bottom 5 rows (by default but you can specify)
# Out:
#              Date Customer Sales Person  Customer_Age Customer_Gender   State  \
# 34862  02/07/2016     High        Kenny            38               M  Ebonyi
# 34863  03/13/2015     High        Kenny            38               M  Ebonyi
# 34864  04/05/2015     High        Kenny            38               M  Ebonyi
# 34865  08/30/2015     High        Kenny            38               M  Ebonyi
# 34866         NaN      NaN          NaN            38             NaN     NaN
#
#       Product_Category Sub_Category Payment Option  Quantity  Unit_Cost  \
# 34862           Phones       IPhone         Online       2.0     1160.0
# 34863           Phones       IPhone         Online       1.0     2049.0
# 34864           Phones       IPhone         Online       3.0      683.0
# 34865           Phones       IPhone         Online       1.0     2320.0
# 34866              NaN          NaN            NaN       NaN        NaN
#
#        Unit_Price
# 34862      985.50
# 34863     1583.00
# ...

# %%
# Dimensionality of the data - Exploring the number of rows and columns

df.shape
# Out:
# (34867, 12)

# %%
# Examine the columns/featuresm of the data

df.columns
# Out:
# Index(['Date', 'Customer', 'Sales Person', 'Customer_Age', 'Customer_Gender',
#        'State', 'Product_Category', 'Sub_Category', 'Payment Option',
#        'Quantity', 'Unit_Cost', 'Unit_Price'],
#       dtype='object')

# %%
# Investigate the dataset for anomalies and data types

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34867 entries, 0 to 34866
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              34866 non-null  object
#  1   Customer          34866 non-null  object
#  2   Sales Person      34866 non-null  object
#  3   Customer_Age      34867 non-null  int64
#  4   Customer_Gender   34866 non-null  object
#  5   State             34866 non-null  object
#  6   Product_Category  34866 non-null  object
#  7   Sub_Category      34866 non-null  object
#  8   Payment Option    34866 non-null  object
#  9   Quantity          34866 non-null  float64
#  10  Unit_Cost         34866 non-null  float64
#  11  Unit_Price        34866 non-null  float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 3.2+ MB

# %%
# Numerical statistical Analysis

df.describe()
# Out:
#        Customer_Age      Quantity     Unit_Cost    Unit_Price
# count  34867.000000  34866.000000  34866.000000  34866.000000
# mean      36.382683      2.002524    349.880567    389.232473
# std       11.112813      0.813936    490.015846    525.319097
# min       17.000000      1.000000      0.670000      0.670000
# 25%       28.000000      1.000000     45.000000     53.670000
# 50%       35.000000      2.000000    150.000000    179.000000
# 75%       44.000000      3.000000    455.000000    521.000000
# max       87.000000      3.000000   3240.000000   5082.000000

# %%
# Categorical statistical Analysis

df.describe(include=["object","bool"])
# Out:
#               Date Customer Sales Person Customer_Gender  State  \
# count        34866    34866        34866           34866  34866
# unique         576        4            7               2     36
# top     03/01/2016      Low       Remota               F  Lagos
# freq           196    13041         6667           17439  10332
#
#        Product_Category Sub_Category Payment Option
# count             34866        34866          34866
# unique                3           17              3
# top         Accessories     Keyboard           Cash
# freq              22534        11112          15911

# %% [markdown]
# ## Dealing with missing data -
#
# 1. MCAR (missing completely at random): These are values that are randomly missing and do not depend on any other values.
# 2. MAR (missing at random): These values are dependent on some additional features.
# 3. MNAR (missing not at random): There is a reason behind why these values are missing.
#
# There are several methods for inputting missing data, including the measure of Central Tendency, regression imputation, and multiple inputation. measures of Central Tendency involves replacing missing values with either the Mean, Median and Mode of the variable, while regression imputation involves using other variables in the dataset to predict missing values.

# %%
# Investigate the missing data

null_vals = df.isnull().sum()
null_vals
# Out:
# Date                1
# Customer            1
# Sales Person        1
# Customer_Age        0
# Customer_Gender     1
# State               1
# Product_Category    1
# Sub_Category        1
# Payment Option      1
# Quantity            1
# Unit_Cost           1
# Unit_Price          1
# dtype: int64

# %%
# Visualize the missing data

plt.figure(figsize=(8,5))
sns.heatmap(df.isnull(), cbar=True, cmap="Blues_r");

# %%
msno.bar(df, color="blue");

# ; used to take unecessary header details

# %%
# Display where the missing data exist in the data 
df[df.isnull().any(axis=1)]
# Out:
#       Date Customer Sales Person  Customer_Age Customer_Gender State  \
# 34866  NaN      NaN          NaN            38             NaN   NaN
#
#       Product_Category Sub_Category Payment Option  Quantity  Unit_Cost  \
# 34866              NaN          NaN            NaN       NaN        NaN
#
#        Unit_Price
# 34866         NaN

# %%
# Drop the missing data

df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Date                0
# Customer            0
# Sales Person        0
# Customer_Age        0
# Customer_Gender     0
# State               0
# Product_Category    0
# Sub_Category        0
# Payment Option      0
# Quantity            0
# Unit_Cost           0
# Unit_Price          0
# dtype: int64

# %%
# Datatime Analysis
df.head(2)
# Out:
#          Date Customer Sales Person  Customer_Age Customer_Gender State  \
# 0  02/19/2016     High        Segun            29               F  Abia
# 1  02/20/2016     High        Segun            29               F  Abia
#
#   Product_Category Sub_Category Payment Option  Quantity  Unit_Cost  \
# 0      Accessories     Keyboard         Online       1.0       80.0
# 1         Clothing  Polo shirts         Online       2.0       24.5
#
#    Unit_Price
# 0       109.0
# 1        28.5

# %%
# Convert the data column into a pandas datetime object
df["Date"]=pd.to_datetime(df["Date"])

# Extract the Year, Month and Quarter
df['year'] = df["Date"].dt.year
df['month'] = df["Date"].dt.month
df['month_name'] = df["Date"].dt.month_name()
df['quarter'] = df["Date"].dt.quarter

df.head(2)
# Out:
#         Date Customer Sales Person  Customer_Age Customer_Gender State  \
# 0 2016-02-19     High        Segun            29               F  Abia
# 1 2016-02-20     High        Segun            29               F  Abia
#
#   Product_Category Sub_Category Payment Option  Quantity  Unit_Cost  \
# 0      Accessories     Keyboard         Online       1.0       80.0
# 1         Clothing  Polo shirts         Online       2.0       24.5
#
#    Unit_Price  year  month month_name  quarter
# 0       109.0  2016      2   February        1
# 1        28.5  2016      2   February        1

# %%
# Group customer age 

def age_group(x):
    if x <= 25:
        return "<=25 Young Adult"
    elif x <= 40:
        return "25-40 Adult"
    elif x <= 50:
        return "41-50 Old Adult"
    else:
        return ">=51 Elders"
    
# Apply function to the data
df["age_group"] = df["Customer_Age"].apply(age_group)
df.head(2)
# Out:
#         Date Customer Sales Person  Customer_Age Customer_Gender State  \
# 0 2016-02-19     High        Segun            29               F  Abia
# 1 2016-02-20     High        Segun            29               F  Abia
#
#   Product_Category Sub_Category Payment Option  Quantity  Unit_Cost  \
# 0      Accessories     Keyboard         Online       1.0       80.0
# 1         Clothing  Polo shirts         Online       2.0       24.5
#
#    Unit_Price  year  month month_name  quarter    age_group
# 0       109.0  2016      2   February        1  25-40 Adult
# 1        28.5  2016      2   February        1  25-40 Adult

# %%
# Cost and Revenue profit calculations
df["cost"] = df["Quantity"]*df["Unit_Cost"]
df["revenue"] = df["Quantity"]*df["Unit_Price"]
df["profit"] = df["revenue"]- df["cost"]
df.head(2)
# Out:
#         Date Customer Sales Person  Customer_Age Customer_Gender State  \
# 0 2016-02-19     High        Segun            29               F  Abia
# 1 2016-02-20     High        Segun            29               F  Abia
#
#   Product_Category Sub_Category Payment Option  Quantity  Unit_Cost  \
# 0      Accessories     Keyboard         Online       1.0       80.0
# 1         Clothing  Polo shirts         Online       2.0       24.5
#
#    Unit_Price  year  month month_name  quarter    age_group  cost  revenue  \
# 0       109.0  2016      2   February        1  25-40 Adult  80.0    109.0
# 1        28.5  2016      2   February        1  25-40 Adult  49.0     57.0
#
#    profit
# 0    29.0
# 1     8.0

# %%
# Profit/Loss grouping
def por (x):
    if x>=0:
        return "Profit"
    else: 
        return "Loss"

df["profit_label"] = df['profit'].apply(por)
df.head(5)
# Out:
#         Date Customer Sales Person  Customer_Age Customer_Gender State  \
# 0 2016-02-19     High        Segun            29               F  Abia
# 1 2016-02-20     High        Segun            29               F  Abia
# 2 2016-02-27     High        Segun            29               F  Abia
# 3 2016-03-12     High        Segun            29               F  Abia
# 4 2016-03-12     High        Segun            29               F  Abia
#
#   Product_Category Sub_Category Payment Option  Quantity  ...  Unit_Price  \
# 0      Accessories     Keyboard         Online       1.0  ...      109.00
# 1         Clothing  Polo shirts         Online       2.0  ...       28.50
# 2      Accessories     Keyboard         Online       3.0  ...        5.00
# 3      Accessories     Keyboard         Online       2.0  ...      116.50
# 4      Accessories     Keyboard         Online       3.0  ...       41.67
#
#    year  month  month_name quarter    age_group    cost  revenue  profit  \
# ...

# %% [markdown]
# # Univarate Analysis
#
#
# Univarate analysis involves analyzing the distribution and summary statisitcs of individual variables/Column/features.
#
# Numerical Column/Features = Numerical Visualization Techniques
# Categorical Column/Feature = Categorical Visualization Techniques

# %%
df.columns
# Out:
# Index(['Date', 'Customer', 'Sales Person', 'Customer_Age', 'Customer_Gender',
#        'State', 'Product_Category', 'Sub_Category', 'Payment Option',
#        'Quantity', 'Unit_Cost', 'Unit_Price', 'year', 'month', 'month_name',
#        'quarter', 'age_group', 'cost', 'revenue', 'profit', 'profit_label'],
#       dtype='object')

# %%
# How customers below to each customer spec
sns.countplot(x="Customer", data=df)
# Out:
# <AxesSubplot:xlabel='Customer', ylabel='count'>

# %% [markdown]
# #### Narration
#
# It appears that there were more customers who purchased products with medium specifications than those who purchased products with high specifications. Additionally, there were fewer customers overall than expected.

# %%
# Investigate te columns affected
df[df["Customer"] == "Hign"].head(3)
# Out:
#             Date Customer Sales Person  Customer_Age Customer_Gender  State  \
# 29770 2015-08-03     Hign       Derick            28               F  Lagos
# 29771 2015-08-04     Hign       Derick            28               F  Lagos
# 29772 2015-08-04     Hign       Derick            28               F  Lagos
#
#       Product_Category Sub_Category Payment Option  Quantity  ...  Unit_Price  \
# 29770           Phones       IPhone           Cash       1.0  ...     2136.00
# 29771      Accessories     Keyboard           Cash       2.0  ...       19.50
# 29772      Accessories     Keyboard           Cash       3.0  ...       18.67
#
#        year  month  month_name quarter    age_group     cost  revenue  profit  \
# 29770  2015      8      August       3  25-40 Adult  2295.00  2136.00  -159.0
# 29771  2015      8      August       3  25-40 Adult    35.00    39.00     4.0
# 29772  2015      8      August       3  25-40 Adult    50.01    56.01     6.0
#
#        profit_label
# ...

# %%
# Correct the spelling of HIGN
df.loc[df["Customer"] == "Hign", "Customer"] = "High"
sns.countplot(x="Customer", data=df)
# Out:
# <AxesSubplot:xlabel='Customer', ylabel='count'>

# %%
df["Customer"].value_counts()
# Out:
# Low       13041
# Medium    12926
# High       8899
# Name: Customer, dtype: int64

# %% [markdown]
# #### Narration
# By examining the quantity of transactions, we can observe that most of the transactions were carried out by customers in the low category, followed by those in the medium and high categories, in that order. The distribution was skewed to the left.

# %%
# Sales Persons - How many transactions by sales person
fig, ax = plt.subplots()
sns.countplot(x=df["Sales Person"], order=df["Sales Person"].value_counts(ascending=False).index, ax=ax)
values = df["Sales Person"].value_counts(ascending=False).values
ax.bar_label(container=ax.containers[0], labels=values);

# %% [markdown]
# #### Narrations
#
# It was noted that among the salespeople, Remota had the highest number of transactions, while Kenny had the lowest. Furthermore, the distribution of transactions was skewed towards the positive end.

# %%
df.columns
# Out:
# Index(['Date', 'Customer', 'Sales Person', 'Customer_Age', 'Customer_Gender',
#        'State', 'Product_Category', 'Sub_Category', 'Payment Option',
#        'Quantity', 'Unit_Cost', 'Unit_Price', 'year', 'month', 'month_name',
#        'quarter', 'age_group', 'cost', 'revenue', 'profit', 'profit_label'],
#       dtype='object')

# %%
# Total transactions by customer Age Group
fig, ax = plt.subplots()

ax = sns.countplot(y=df["age_group"], order=df["age_group"].value_counts(ascending=False).index, ax=ax)
values = df["age_group"].value_counts(ascending=False).values
ax.bar_label(container=ax.containers[0], labels=values);

# %% [markdown]
# #### Narration about your observations
#
#
# The population count of the adult age category was higher than that of any other group. The old adult group came second, followed by adults, and finally the elders.

# %%
df.columns
# Out:
# Index(['Date', 'Customer', 'Sales Person', 'Customer_Age', 'Customer_Gender',
#        'State', 'Product_Category', 'Sub_Category', 'Payment Option',
#        'Quantity', 'Unit_Cost', 'Unit_Price', 'year', 'month', 'month_name',
#        'quarter', 'age_group', 'cost', 'revenue', 'profit', 'profit_label'],
#       dtype='object')

# %%
# Total Transaction by Customer Gender

fig, ax = plt.subplots(figsize=(5, 5))
count = Counter(df["Customer_Gender"])
ax.pie(count.values(), labels=count.keys(), autopct=lambda p:f'{p:.2f}%')
ax.set_title("Percentage of transactions by Gender")
plt.show()

# %% [markdown]
# ## Narrations of the Total Transaction by Customer Gender
#
# From the visualization, it can be observed that the  Female half is slightly higher than that of the male gender. Therefore, it is relatively balanced.

# %%
# Total transaction by state
plt.figure(figsize=(20,5))

topten = df["State"].value_counts().head(10)

sns.countplot(x="State", data=df, order=topten.index);
print(topten)
# Out:
# Lagos        10332
# Abuja         6421
# Abia          5206
# Adamawa       2446
# Akwa Ibom     1287
# Edo           1229
# Anambra       1171
# Bauchi        1112
# Bayelsa       1092
# Benue          869
# Name: State, dtype: int64

# %% [markdown]
# #### Narration
# According to the information presented in the chart, Lagos State has the greatest number of occurrences, while Benue has the smallest.

# %%
# Product Category
# Sub Category
# Payment Options
# Month Name

# %%
# Total transaction by Profit or Loss

fig, ax = plt.subplots(figsize=(5, 5))
count = Counter(df["profit_label"])
ax.pie(count.values(), labels=count.keys(), autopct=lambda p:f'{p:.2f}%')
ax.set_title("Percentage of transactions by Profit")
plt.show()

# %%
df.columns
# Out:
# Index(['Date', 'Customer', 'Sales Person', 'Customer_Age', 'Customer_Gender',
#        'State', 'Product_Category', 'Sub_Category', 'Payment Option',
#        'Quantity', 'Unit_Cost', 'Unit_Price', 'year', 'month', 'month_name',
#        'quarter', 'age_group', 'cost', 'revenue', 'profit', 'profit_label'],
#       dtype='object')

# %% [markdown]
# #### Narration:
# The percentage of profit per transaction exceeded the percentage of loss.

# %% [markdown]
# ## Numerical data Visualization

# %% [markdown]
# ### Narration
# The initial boxplot illustrates the amount of products that were purchased, and it appears to exhibit a highly regular normal distribution.
#
# The second boxplot exhibits a left-skewed distribution, with a few outliers occurring between 2500 and 3500, indicating that the mean is greater than the median and mode.
#
# Similarly, the third boxplot also displays a left-skewed distribution with outliers between 4000 and 5000, indicating that the mean is greater than the median and mode.
#
# Finally, the histogram portrays a rise in profits between the 0-600 range.

# %%
# Quantity, Cost and Revenue and Profit - Subplot

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(15,10))

sns.boxplot(x="Quantity", data=df, ax=axs[0,0])
axs[0,0].set_title("Boxplot on Quantity sold")

sns.boxplot(x="cost", data=df, ax=axs[0,1])
axs[0,1].set_title("Boxplot on cost")

sns.boxplot(x="revenue", data=df, ax=axs[1,0])
axs[1,0].set_title("Boxplot on revenue")

sns.histplot(x="profit", data=df, ax=axs[1,1])
axs[1,1].set_title("Histplot on Profit");

# %% [markdown]
# #### Narrative
# The above plots shows Quantity, Cost and Revenue and Profit - Subplot.
# The Quantity plot of quantity sold shows an even distirbution whereas the second cost boxplot shows a positive distribution with soem outliers. Revenue boxplot shows a positive distirbution with outliers. lasly, the histoplot on profit shows distribution of profit tilting to the positive and sligtly to the left.

# %% [markdown]
# ### Bivarate Analysis
#
# Bivarate analysis involves analyzing the relationship between two varaibles.
#
# Focus on Profit

# %%
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(25,10))

cust_prof = df.groupby("Customer")["profit"].sum().reset_index()
sns.barplot(x='Customer', data=cust_prof, y='profit', ax=axs[0,0])
axs[0,0].set_title("Total profit by customer type")

sp_prof = df.groupby("Sales Person")["profit"].sum().reset_index()
sns.barplot(x='Sales Person', data=sp_prof, y='profit', ax=axs[0,1])
axs[0,0].set_title("Total profit by Sales Person")

ag_prof = df.groupby("age_group")["profit"].sum().reset_index()
sns.barplot(x='age_group', data=ag_prof, y='profit', ax=axs[0,2])
axs[0,0].set_title("Total profit by age_group")

pc_prof = df.groupby("Product_Category")["profit"].sum().reset_index()
sns.barplot(y='Product_Category', data=pc_prof, x='profit', ax=axs[1,0])
axs[0,0].set_title("Total profit by Product_Category")

po_prof = df.groupby("Payment Option")["profit"].sum().reset_index()
sns.barplot(y='Payment Option', data=po_prof, x='profit', ax=axs[1,1])
axs[0,0].set_title("Total profit by Payment Option")

sc_prof = df.groupby("Sub_Category")["profit"].sum().reset_index()
sns.barplot(y='Sub_Category', data=sc_prof, x='profit', ax=axs[1,2])
axs[0,0].set_title("Total profit by Sub_Category");

# %% [markdown]
# ## Narration
#
# Regarding the sub_category barplot, we can see that the Low customer category generated the highest profit, followed by the medium, high, and lastly, the highest category.
#
# When examining the Profit by sales Person, it is apparent that Feyisola had the most substantial profit margin, while Derick had the smallest.
#
# Based on the Profit by age_group data, we can conclude that individuals aged between 25-40 were the most profitable, while those aged 51 years and above were the least profitable. The chart is positively skewed.
#
# In terms of Product_Category, Accessories were more profitable than Clothing and Phones. The chart formed is positively skewed.
#
# When analyzing Payment Options, cash generated the most profit.
#
# Concerning Sub_Category, both Wrist watches and Keyboards generated profits exceeding 50000, making them the two most profitable items.

# %%
#Numerical Columns

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(25,10))

sns.boxplot(x='Quantity', y='profit', data=df, ax=axs[0,0])
axs[0,0].set_title("Quantity and Profit")

sns.boxplot(x='Product_Category', y='profit', data=df, ax=axs[0,1])
axs[0,1].set_title("Product_Category and Profit")

sns.boxplot(x='age_group', y='profit', data=df, ax=axs[1,0])
axs[1,0].set_title("age_group and Profit")

sns.scatterplot(x='Customer_Age', y='profit', data=df, ax=axs[1,1])
axs[1,1].set_title("Customer_Age and Profit");

# %% [markdown]
# #### Narration
#
# It was noticed that the 1.0 Quantity yielded greater profits in comparison to 2.0 and 3.0. However, 3.0 experienced greater losses. Outliers were present in all three quantities.
#
# The product category chart indicated that accessories generated the highest profits, followed by phones and clothing with the lowest. Accessories had more outliers and recorded fewer losses.
#
# The plot displaying age groups showed a decline in profits for individuals between the ages of 25-40. Among all age groups, adults experienced the greatest loss, while young adults (below the age of 25) experienced the least loss. Interestingly, despite the fact that adults aged 25-40 had the highest profit, they also experienced the most significant loss.
#
# The age distribution of customers was concentrated between 20-50 years old and became more dispersed beyond age 90.

# %% [markdown]
# #### Multivarate Analysis
# Multivarate Analysis involves analyzing the relationship between three or more variables.

# %%
#Product_Category agaisnt cost, Revenue and profit

procat = df.groupby("Product_Category")[["cost", "revenue", "profit"]].sum().reset_index()
procat = pd.melt(procat, id_vars="Product_Category", var_name="Metric", value_name="Total")
sns.barplot(data=procat, x='Product_Category', y="Total", hue="Metric");

# %% [markdown]
# Narration:
# the following trend was observed;
# Accessories generated a revenue of approximately 0.8 and incurred a cost of 0.6, resulting in a higher profit margin compared to the other products. On the other hand, despite generating the most revenue of 1.1, Phones had a higher cost of about 1.08, which resulted in a relatively low profit of 0.05. Clothing had a revenue of 0.3 and a cost of 0.29, resulting in a profit of 0.1.

# %%
procat
# Out:
#   Product_Category   Metric        Total
# 0      Accessories     cost   6041896.06
# 1         Clothing     cost   2892324.94
# 2           Phones     cost  11148745.02
# 3      Accessories  revenue   7420663.12
# 4         Clothing  revenue   3437556.95
# 5           Phones  revenue  11486354.63
# 6      Accessories   profit   1378767.06
# 7         Clothing   profit    545232.01
# 8           Phones   profit    337609.61

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x='month', y='profit', data=df, hue='year')
# Out:
# <AxesSubplot:xlabel='month', ylabel='profit'>

# %%
# Using pivot table
df.pivot_table(values='profit', index='year', columns='month', aggfunc='sum')
# Out:
# month         1          2          3          4          5          6   \
# year
# 2015    -5778.70   -4079.65   -8163.79   -4945.69   -7801.45   -8690.61
# 2016   280204.25  263640.18  299777.67  307746.51  356915.59  357549.86
#
# month         7         8         9         10       11        12
# year
# 2015    15104.47  65926.24  62172.33  62950.66  54480.9  67448.12
# 2016   107151.79       NaN       NaN       NaN      NaN       NaN

# %% [markdown]
# #### Narration:
# From month one to month six 2015, there was a decrease in earnings, but in the seventh month, profits surpassed the previous downward trend. However, from month eight to month twelve 2015, earnings declined once again. Moving on to 2016, there was a consistent profit from month one to month seven.

# %%
# Customer Gender, Age group and profit

plt.figure(figsize=(15,5))
sns.barplot(x="Customer_Gender", y='profit', data=df, hue="age_group");

# %% [markdown]
# #### Narration
#
# Male Category:
# According to the graph, the age groups that generated the most profit were those between 25-40 and 41-50 years old, while the age group of 25 and below had the lowest profit.
#
# Female Category:
# Based on the plot, it can be observed that the age groups that contributed the most to the profit were those between 41-50 and those who were 51 years old and above. On the other hand, the age group of 25 and below had the lowest profit.
#
# Both:
# The plot shows that the age group of 25 and below had the lowest profit, while the age groups between 25-40 and 41-50 contributed the most to the profit, for both male and female categories.

# %%
df.columns
# Out:
# Index(['Date', 'Customer', 'Sales Person', 'Customer_Age', 'Customer_Gender',
#        'State', 'Product_Category', 'Sub_Category', 'Payment Option',
#        'Quantity', 'Unit_Cost', 'Unit_Price', 'year', 'month', 'month_name',
#        'quarter', 'age_group', 'cost', 'revenue', 'profit', 'profit_label'],
#       dtype='object')

# %%
# Correlation
a = df.corr()
f, ax = plt.subplots(figsize=(15,8))
sns.heatmap(a, vmax=.8, square=True, annot=True);

# %% [markdown]
# #### Narration
#
# The analysis of the correlation matrix revealed the following findings:
#
# -There is no significant correlation between Profit and Customer Age, as indicated by the correlation coefficient of 0.014 and 0.028, respectively.
#
# -Profit and Revenue exhibit a strong positive correlation, with a correlation coefficient of 0.4.
#
# -There is a weak positive correlation between Profit and Cost, with a correlation coefficient of 0.2.
#
# -There is no correlation between Profit and Quantity, with a correlation coefficient of 0.0031.
#
# -Profit and Unit Price show a positive correlation, but it is not strong, as indicated by the correlation coefficient of 0.34.
#
# -Month has a negative correlation, suggesting a decline in some aspect related to it.
#
# -Additionally, the analysis found perfect correlation relationships between the following pairs:
#
# -Unit Cost and Unit Cost
#
# -Quarter and Quarter
#
# -Quantity and Quantity
#
# -Revenue and Revenue
#
#
# -Cost and Cost
#
# -Month and Month
#
# -Year and Year
#
# -Unit Price and Unit Price.

# %%
sns.pairplot(df, size=2.5);
# Out:
# C:\Users\Uncle Baby\Pictures\Anaconda 2023\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Narration
#
# -As revenue grows, both profit and revenue increase in magnitude.
#
#
# -The data displayed many groups of data points in customer_age, profit, revenue, cost, and unit_cost, with only a small number of data points lying outside these groups.
#
#
# -The correlation between profit, revenue, and cost is positively linear, with only a few data points falling outside this pattern.
#
#
# -There is a relationship between profit, revenue, and cost as they vary by month.
